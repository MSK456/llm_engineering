# %% [markdown]
# # End of week 1 exercise
#
# To demonstrate your familiarity with OpenAI API, and also Ollama, build a tool that takes a technical question,
# and responds with an explanation. This is a tool that you will be able to use yourself during the course!

# %%
import os
from openai import OpenAI
from dotenv import load_dotenv

# 1. Load your secret keys from the .env file
load_dotenv(override=True)
google_api_key = os.getenv("GOOGLE_API_KEY")

# 2. Setup Client A: The Cloud (Google Gemini)
# We use the base_url trick to route the OpenAI library to Google!
cloud_client = OpenAI(
    base_url="https://generativelanguage.googleapis.com/v1beta/openai/",
    api_key=google_api_key
)

# 3. Setup Client B: Local Hardware (Ollama)
local_client = OpenAI(
    base_url="http://localhost:11434/v1",
    api_key="ollama" # Ollama requires text here, but doesn't actually check it
)

# %%
# constants

MODEL_GPT = 'gemini-2.5-flash'
MODEL_LLAMA = 'llama3.2'

# %%
# set up environment

# %%
# here is the question; type over this to ask something new

question = """
Please explain what this code does and why:
yield from {book.get("author") for book in books if book.get("author")}
"""

# %%
# Get gpt-4o-mini to answer, with streaming

# %%
# Get Llama 3.2 to answer

# %%
import os
from openai import OpenAI
from dotenv import load_dotenv

# 1. Load your secret keys from the .env file
load_dotenv(override=True)
google_api_key = os.getenv("GOOGLE_API_KEY")

# 2. Setup Client A: The Cloud (Google Gemini)
# We use the base_url trick to route the OpenAI library to Google!
cloud_client = OpenAI(
    base_url="https://generativelanguage.googleapis.com/v1beta/openai/",
    api_key=google_api_key
)

# 3. Setup Client B: Local Hardware (Ollama)
local_client = OpenAI(
    base_url="http://localhost:11434/v1",
    api_key="ollama" # Ollama requires text here, but doesn't actually check it
)

def tech_tutor(question, use_local=False):
    """
    Takes a technical question and returns an expert explanation.
    Set use_local=True to use Ollama (Free/Private).
    Set use_local=False to use Gemini (Cloud/Smarter).
    """
    
    # 4. Give the AI its persona and rules
    messages = [
        {"role": "system", "content": "You are a senior LLM engineer and coding tutor. Explain the following technical concept clearly, using an analogy or short example if it helps."},
        {"role": "user", "content": question}
    ]
    
    # 5. Route the request based on your toggle switch!
    if use_local:
        print("🧠 Routing to local hardware (Ollama / Llama 3.2)...")
        response = local_client.chat.completions.create(
            model="llama3.2", # Change to "llama3.2:1b" if needed
            messages=messages
        )
    else:
        print("☁️ Routing to the cloud (Google Gemini)...")
        response = cloud_client.chat.completions.create(
            model="gemini-2.5-flash", # Make sure we ask for the Google model!
            messages=messages
        )
        
    # 6. Extract and return the answer
    return response.choices[0].message.content

# ==========================================
# TEST YOUR TOOL!
# ==========================================

my_question = "What exactly does the 'base_url' parameter do when setting up an API client?"

# Test 1: Run it locally for free!
print("--- LOCAL TEST (OLLAMA) ---")
answer_local = tech_tutor(my_question, use_local=True)
print(answer_local)

print("\n" + "="*50 + "\n")

# Test 2: Run it on the cloud!
print("--- CLOUD TEST (GEMINI) ---")
answer_cloud = tech_tutor(my_question, use_local=False)
print(answer_cloud)
# Out:
# --- LOCAL TEST (OLLAMA) ---
# 🧠 Routing to local hardware (Ollama / Llama 3.2)...
# When setting up an API client in many programming languages and frameworks (like Flask in Python), you often come across a setting called `base_url`. This can be a bit confusing if you're not familiar with it, but I'm here to help break it down.
#
# **What is the base URL?**
#
# The `base_url` parameter is essentially the foundation of your API client. It's like the starting point or the root address where all subsequent requests will be sent to the server.
#
# Think of it this way: Imagine you're sending a letter to a friend. The address on the envelope (envelope being your base URL) gives the postal service direction to deliver the mail to the right place. In the same way, when your API client uses a `base_url`, the request is wrapped around that URL, providing context for the server about where to find the resources it's requesting.
#
# **Setting the base_url**
#
# When setting up an API client and configuring the base URL:
#
# 1. You define what URL you want as the starting point.
# 2. All future requests are appended with this starting point (using path segments, query parameters, etc.)
#
# Here is a simple Python example using Flask:
# ```python
# from flask import Flask, request, jsonify
#
# app = Flask(__name__)
#
# def make_request(method, resource, **kwargs):
#     # Assuming app.url_map exists for simplicity
#     url = app.url_map.get_rule(resource + method)
#     if not url:
#         raise ValueError(f"Resource {resource} doesn't exist")
#
#     return request.urljoin(url), kwargs
#
# base_url = "https://example.com/api"
# base_resource = ""
#
# @app.route(base_resource, methods=["POST"])
# def create_resource():
#     # Receive data from the client and send a response
#     pass
#
# # Create a new resource at the "/resources" path under the base URL.
# make_request(
#     "get",
#     "resources",
# )
#
# # Update an existing resource at "/users/123".
# make_request(
#     "patch",
#     f"{base_resource}users/123",
#     data={"name": "new name"}
# )
# ```
#
# In this example, `Base URL` is "https://example.com/api". Requests will be sent under that structure.
#
# **So what can you do with the base_url parameter?**
#
# The power of a well-configured `base_url` allows you to:
#
# * Build hierarchical structures within your API.
# * Create robust and readable request patterns using RESTful endpoints.
# * Establish commonality in client logic across different services or domains.
#
# Let me know if you're still feeling puzzled, I'd be happy to provide more details!
#
# ==================================================
#
# --- CLOUD TEST (GEMINI) ---
# ☁️ Routing to the cloud (Google Gemini)...
# The `base_url` parameter, when setting up an API client, acts as the **default starting point or root address for all API requests** made by that client.
#
# Think of it like the **main street address for a large building that contains many different offices or apartments.**
#
# ### Analogy: A Big Office Building
#
# Imagine you're trying to send mail to different departments within a large corporate headquarters.
#
# *   **The Building's Street Address:** `123 Tech Park Blvd, Suite 100, Anytown, CA`
# *   **Specific Department Addresses (Endpoints):**
#     *   `/sales/inquiries`
#     *   `/support/tickets`
#     *   `/hr/job_applications`
#
# If you had to write the full street address *every single time* you wanted to send mail to a different department, it would be incredibly repetitive, prone to typos, and a pain if the company ever moved buildings.
#
# **The `base_url` is like pre-filling the building's street address on all your outgoing envelopes.**
#
# ### What it *Exactly* Does:
#
# When you configure an API client with a `base_url`, you're telling it:
#
# 1.  **"This is the fixed, unchanging part of the URL for all subsequent requests I'm going to make."**
# 2.  **"When I give you a *relative path* (an endpoint), you should automatically combine it with this `base_url` to form the complete, absolute URL."**
#
# So, if your `base_url` is `https://api.example.com/v1/` and you then make a request to the endpoint `/users`, the client automatically constructs the full URL as:
#
# `https://api.example.com/v1/users`
#
# ### Why is this so useful? (Key Benefits)
#
# 1.  **DRY (Don't Repeat Yourself):** You define the base URL once, centralizing it. This avoids scattering the full domain and API version across dozens of function calls.
# 2.  **Maintainability:** If the API's domain changes (e.g., from `api.example.com` to `api.newdomain.com`) or the API version updates (e.g., from `/v1/` to `/v2/`), you only need to change it in *one single place* in your client configuration.
# 3.  **Readability:** Your code becomes cleaner and easier to understand, as the API call methods only specify the *specific resource* they are trying to access (e.g., `client.get('/products')` instead of `client.get('https://api.example.com/v1/products')`).
# 4.  **Reduced Errors:** Less repetition means fewer chances for typos when typing out long URLs.
# 5.  **Environment Flexibility:** It makes it easy to switch between development, staging, and production environments. You might have different `base_url` values for each:
#     *   `https://dev-api.example.com/v1/`
#     *   `https://staging-api.example.com/v1/`
#     *   `https://api.example.com/v1/`
#
# ### Short Code Example (Conceptual Python)
#
# ```python
# import requests
#
# # --- Without base_url (less ideal) ---
# # Each request needs the full URL
# response1 = requests.get('https://api.github.com/users/octocat/repos')
# response2 = requests.get('https://api.github.com/users/octocat/followers')
#
# # --- With base_url (much better!) ---
# # Create a session or client object with a base_url
# class GitHubClient:
#     def __init__(self, base_url):
#         self.base_url = base_url
#         self.session = requests.Session() # Using requests.Session is common for API clients
#
#     def get(self, endpoint):
#         # The magic: base_url + endpoint
#         full_url = f"{self.base_url}{endpoint}"
#         print(f"Making request to: {full_url}")
#         return self.session.get(full_url)
#
# # Instantiate our client with the base URL
# github_client = GitHubClient('https://api.github.com/')
#
# # Now, we only provide the *relative path* or *endpoint*
# user_repos = github_client.get('users/octocat/repos')
# user_followers = github_client.get('users/octocat/followers')
# user_gists = github_client.get('users/octocat/gists')
#
# print("\nUser Repositories:")
# print(user_repos.json()[0]['name']) # Example output: 'Spoon-Knife'
#
# print("\nUser Followers:")
# print(user_followers.json()[0]['login']) # Example output: 'rtyler'
# ```
#
# In summary, `base_url` streamlines your API interactions by abstracting away the common, repetitive part of your API's address, leading to cleaner, more robust, and easier-to-maintain code.
